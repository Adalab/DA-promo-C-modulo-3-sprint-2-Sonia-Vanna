# %%
import pandas as pd
import numpy as np

# %%
df_country = pd.read_csv("ufo_concat_country.csv",index_col=0)

# %%
df_country.head(2)
# Out:
#           Reportedtimestamp   eventdate eventtime   shape  duration  \
# 0  1977-04-04T04:02:23.340Z  1977-03-31     23:46  circle         4
# 1  1982-11-22T02:06:32.019Z  1982-11-15     22:04    disk         4
#
#    witnesses        weather firstname    lastname   latitude   longitude  \
# 0          1           rain       Ila   Bashirian  47.329444 -122.578889
# 1          1  partly cloudy  Eriberto  Runolfsson  52.664913   -1.034894
#
#   sighting physicalevidence contact researchoutcome         country
# 0        Y                N       N       explained   United States
# 1        Y                Y       N       explained  United Kingdom

# %%
df_city = pd.read_csv("sonia_df_ufo_city.csv",index_col=0)

# %%
df_city.head(2)
# Out:
#    event_date   latitude   longitude        city
# 0  1977-03-31  47.329444 -122.578889  Gig Harbor
# 1  1982-11-15  52.664913   -1.034894   Charnwood

# %%
lista_pais = [df_country,df_city]

# %%
df_ufo_concat = pd.concat(lista_pais, axis=1)

# %%
df_ufo_concat.columns
# Out:
# Index(['Reportedtimestamp', 'eventdate', 'eventtime', 'shape', 'duration',
#        'witnesses', 'weather', 'firstname', 'lastname', 'latitude',
#        'longitude', 'sighting', 'physicalevidence', 'contact',
#        'researchoutcome', 'country', 'event_date', 'latitude', 'longitude',
#        'city'],
#       dtype='object')

# %%
df_ufo_concat.drop(['event_date', 'latitude', 'longitude'], axis=1, inplace=True )
df_ufo_concat.head()
# Out:
#           Reportedtimestamp   eventdate eventtime   shape  duration  \
# 0  1977-04-04T04:02:23.340Z  1977-03-31     23:46  circle         4
# 1  1982-11-22T02:06:32.019Z  1982-11-15     22:04    disk         4
# 2  1992-12-07T19:06:52.482Z  1992-12-07     19:01  circle        49
# 3  2011-02-24T21:06:34.898Z  2011-02-21     20:56    disk        13
# 4  1991-03-09T16:18:45.501Z  1991-03-09     11:42  circle        17
#
#    witnesses        weather firstname    lastname sighting physicalevidence  \
# 0          1           rain       Ila   Bashirian        Y                N
# 1          1  partly cloudy  Eriberto  Runolfsson        Y                Y
# 2          1          clear    Miller     Watsica        Y                N
# 3          1  partly cloudy   Clifton   Bechtelar        Y                N
# 4          1  mostly cloudy     Jayda       Ebert        Y                N
#
#   contact researchoutcome         country        city
# ...

# %%
df_ufo_concat.to_csv("ufo_concat_final.csv")
